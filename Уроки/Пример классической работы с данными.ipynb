# %%
import pandas as pd

# %%
# !wget https://github.com/yutkin/Lenta.Ru-News-Dataset/releases/download/v1.0/lenta-ru-news.csv.gz
# Out:
# "wget" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %%
from corus import load_lenta
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from corus import load_lenta
#
# File ~\PycharmProjects\texts_attribution\venv\Lib\site-packages\corus\__init__.py:2
# ----> 2 from .sources import *  # noqa
#
# File ~\PycharmProjects\texts_attribution\venv\Lib\site-packages\corus\sources\__init__.py:13
#      11 from .buriy import *  # noqa
#      12 from .mokoron import *  # noqa
# ---> 13 from .wiki import load_wiki  # noqa
#      14 from .ods import *  # noqa
#      15 from .ria import *  # noqa
#
# File ~\PycharmProjects\texts_attribution\venv\Lib\site-packages\corus\sources\wiki.py:7
#       5 from corus.record import Record
#       6 from corus.io import load_bz2_lines
# ----> 7 from corus.third.WikiExtractor import (
#       8     options,
#       9     pages_from,
#      10     Extractor
#      11 )
#      14 options.write_json = True
#      17 class WikiRecord(Record):
#
# File ~\PycharmProjects\texts_attribution\venv\Lib\site-packages\corus\third\WikiExtractor.py:2447
#    2445 EXT_LINK_URL_CLASS = r'[^][<>"\x00-\x20\x7F\s]'
#    2446 ANCHOR_CLASS = r'[^][\x00-\x08\x0a-\x1F]'
# -> 2447 ExtLinkBracketedRegex = re.compile(
#    2448     '\[(((?i)' + '|'.join(wgUrlProtocols) + ')' + EXT_LINK_URL_CLASS + r'+)' +
#    2449     r'\s*((?:' + ANCHOR_CLASS + r'|\[\[' + ANCHOR_CLASS + r'+\]\])' + r'*?)\]',
#    2450     re.S | re.U)
#    2451 # A simpler alternative:
#    2452 # ExtLinkBracketedRegex = re.compile(r'\[(.*?)\](?!])')
#    2454 EXT_IMAGE_REGEX = re.compile(
#    2455     r"""^(http://|https://)([^][<>"\x00-\x20\x7F\s]+)
#    2456     /([A-Za-z0-9_.,~%\-+&;#*?!=()@\x80-\xFF]+)\.((?i)gif|png|jpg|jpeg)$""",
#    2457     re.X | re.S | re.U)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\__init__.py:227, in compile(pattern, flags)
#     225 def compile(pattern, flags=0):
#     226     "Compile a regular expression pattern, returning a Pattern object."
# --> 227     return _compile(pattern, flags)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\__init__.py:294, in _compile(pattern, flags)
#     288     import warnings
#     289     warnings.warn("The re.TEMPLATE/re.T flag is deprecated "
#     290               "as it is an undocumented flag "
#     291               "without an obvious purpose. "
#     292               "Don't use it.",
#     293               DeprecationWarning)
# --> 294 p = _compiler.compile(pattern, flags)
#     295 if not (flags & DEBUG):
#     296     if len(_cache) >= _MAXCACHE:
#     297         # Drop the oldest item
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_compiler.py:743, in compile(p, flags)
#     741 if isstring(p):
#     742     pattern = p
# --> 743     p = _parser.parse(p, flags)
#     744 else:
#     745     pattern = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_parser.py:980, in parse(str, flags, state)
#     977 state.flags = flags
#     978 state.str = str
# --> 980 p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     981 p.state.flags = fix_flags(str, p.state.flags)
#     983 if source.next is not None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_parser.py:455, in _parse_sub(source, state, verbose, nested)
#     453 start = source.tell()
#     454 while True:
# --> 455     itemsappend(_parse(source, state, verbose, nested + 1,
#     456                        not nested and not items))
#     457     if not sourcematch("|"):
#     458         break
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_parser.py:863, in _parse(source, state, verbose, nested, first)
#     860     group = None
#     861 sub_verbose = ((verbose or (add_flags & SRE_FLAG_VERBOSE)) and
#     862                not (del_flags & SRE_FLAG_VERBOSE))
# --> 863 p = _parse_sub(source, state, sub_verbose, nested + 1)
#     864 if not source.match(")"):
#     865     raise source.error("missing ), unterminated subpattern",
#     866                        source.tell() - start)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_parser.py:455, in _parse_sub(source, state, verbose, nested)
#     453 start = source.tell()
#     454 while True:
# --> 455     itemsappend(_parse(source, state, verbose, nested + 1,
#     456                        not nested and not items))
#     457     if not sourcematch("|"):
#     458         break
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_parser.py:863, in _parse(source, state, verbose, nested, first)
#     860     group = None
#     861 sub_verbose = ((verbose or (add_flags & SRE_FLAG_VERBOSE)) and
#     862                not (del_flags & SRE_FLAG_VERBOSE))
# --> 863 p = _parse_sub(source, state, sub_verbose, nested + 1)
#     864 if not source.match(")"):
#     865     raise source.error("missing ), unterminated subpattern",
#     866                        source.tell() - start)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_parser.py:455, in _parse_sub(source, state, verbose, nested)
#     453 start = source.tell()
#     454 while True:
# --> 455     itemsappend(_parse(source, state, verbose, nested + 1,
#     456                        not nested and not items))
#     457     if not sourcematch("|"):
#     458         break
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_parser.py:841, in _parse(source, state, verbose, nested, first)
#     839 if flags is None:  # global flags
#     840     if not first or subpattern:
# --> 841         raise source.error('global flags not at the start '
#     842                            'of the expression',
#     843                            source.tell() - start)
#     844     verbose = state.flags & SRE_FLAG_VERBOSE
#     845     continue
#
# error: global flags not at the start of the expression at position 4

# %%
from corus import load_ods_meduza
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from corus import load_ods_meduza
#
# File ~\PycharmProjects\texts_attribution\venv\Lib\site-packages\corus\__init__.py:2
# ----> 2 from .sources import *  # noqa
#
# File ~\PycharmProjects\texts_attribution\venv\Lib\site-packages\corus\sources\__init__.py:13
#      11 from .buriy import *  # noqa
#      12 from .mokoron import *  # noqa
# ---> 13 from .wiki import load_wiki  # noqa
#      14 from .ods import *  # noqa
#      15 from .ria import *  # noqa
#
# File ~\PycharmProjects\texts_attribution\venv\Lib\site-packages\corus\sources\wiki.py:7
#       5 from corus.record import Record
#       6 from corus.io import load_bz2_lines
# ----> 7 from corus.third.WikiExtractor import (
#       8     options,
#       9     pages_from,
#      10     Extractor
#      11 )
#      14 options.write_json = True
#      17 class WikiRecord(Record):
#
# File ~\PycharmProjects\texts_attribution\venv\Lib\site-packages\corus\third\WikiExtractor.py:2447
#    2445 EXT_LINK_URL_CLASS = r'[^][<>"\x00-\x20\x7F\s]'
#    2446 ANCHOR_CLASS = r'[^][\x00-\x08\x0a-\x1F]'
# -> 2447 ExtLinkBracketedRegex = re.compile(
#    2448     '\[(((?i)' + '|'.join(wgUrlProtocols) + ')' + EXT_LINK_URL_CLASS + r'+)' +
#    2449     r'\s*((?:' + ANCHOR_CLASS + r'|\[\[' + ANCHOR_CLASS + r'+\]\])' + r'*?)\]',
#    2450     re.S | re.U)
#    2451 # A simpler alternative:
#    2452 # ExtLinkBracketedRegex = re.compile(r'\[(.*?)\](?!])')
#    2454 EXT_IMAGE_REGEX = re.compile(
#    2455     r"""^(http://|https://)([^][<>"\x00-\x20\x7F\s]+)
#    2456     /([A-Za-z0-9_.,~%\-+&;#*?!=()@\x80-\xFF]+)\.((?i)gif|png|jpg|jpeg)$""",
#    2457     re.X | re.S | re.U)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\__init__.py:227, in compile(pattern, flags)
#     225 def compile(pattern, flags=0):
#     226     "Compile a regular expression pattern, returning a Pattern object."
# --> 227     return _compile(pattern, flags)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\__init__.py:294, in _compile(pattern, flags)
#     288     import warnings
#     289     warnings.warn("The re.TEMPLATE/re.T flag is deprecated "
#     290               "as it is an undocumented flag "
#     291               "without an obvious purpose. "
#     292               "Don't use it.",
#     293               DeprecationWarning)
# --> 294 p = _compiler.compile(pattern, flags)
#     295 if not (flags & DEBUG):
#     296     if len(_cache) >= _MAXCACHE:
#     297         # Drop the oldest item
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_compiler.py:743, in compile(p, flags)
#     741 if isstring(p):
#     742     pattern = p
# --> 743     p = _parser.parse(p, flags)
#     744 else:
#     745     pattern = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_parser.py:980, in parse(str, flags, state)
#     977 state.flags = flags
#     978 state.str = str
# --> 980 p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     981 p.state.flags = fix_flags(str, p.state.flags)
#     983 if source.next is not None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_parser.py:455, in _parse_sub(source, state, verbose, nested)
#     453 start = source.tell()
#     454 while True:
# --> 455     itemsappend(_parse(source, state, verbose, nested + 1,
#     456                        not nested and not items))
#     457     if not sourcematch("|"):
#     458         break
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_parser.py:863, in _parse(source, state, verbose, nested, first)
#     860     group = None
#     861 sub_verbose = ((verbose or (add_flags & SRE_FLAG_VERBOSE)) and
#     862                not (del_flags & SRE_FLAG_VERBOSE))
# --> 863 p = _parse_sub(source, state, sub_verbose, nested + 1)
#     864 if not source.match(")"):
#     865     raise source.error("missing ), unterminated subpattern",
#     866                        source.tell() - start)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_parser.py:455, in _parse_sub(source, state, verbose, nested)
#     453 start = source.tell()
#     454 while True:
# --> 455     itemsappend(_parse(source, state, verbose, nested + 1,
#     456                        not nested and not items))
#     457     if not sourcematch("|"):
#     458         break
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_parser.py:863, in _parse(source, state, verbose, nested, first)
#     860     group = None
#     861 sub_verbose = ((verbose or (add_flags & SRE_FLAG_VERBOSE)) and
#     862                not (del_flags & SRE_FLAG_VERBOSE))
# --> 863 p = _parse_sub(source, state, sub_verbose, nested + 1)
#     864 if not source.match(")"):
#     865     raise source.error("missing ), unterminated subpattern",
#     866                        source.tell() - start)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_parser.py:455, in _parse_sub(source, state, verbose, nested)
#     453 start = source.tell()
#     454 while True:
# --> 455     itemsappend(_parse(source, state, verbose, nested + 1,
#     456                        not nested and not items))
#     457     if not sourcematch("|"):
#     458         break
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_parser.py:841, in _parse(source, state, verbose, nested, first)
#     839 if flags is None:  # global flags
#     840     if not first or subpattern:
# --> 841         raise source.error('global flags not at the start '
#     842                            'of the expression',
#     843                            source.tell() - start)
#     844     verbose = state.flags & SRE_FLAG_VERBOSE
#     845     continue
#
# error: global flags not at the start of the expression at position 4

# %%
from re
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 re.__version__
#
# NameError: name 're' is not defined

# %%
from corus import load_ods_meduza
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from corus import load_ods_meduza
#
# File ~\PycharmProjects\texts_attribution\venv\Lib\site-packages\corus\__init__.py:2
# ----> 2 from .sources import *  # noqa
#
# File ~\PycharmProjects\texts_attribution\venv\Lib\site-packages\corus\sources\__init__.py:13
#      11 from .buriy import *  # noqa
#      12 from .mokoron import *  # noqa
# ---> 13 from .wiki import load_wiki  # noqa
#      14 from .ods import *  # noqa
#      15 from .ria import *  # noqa
#
# File ~\PycharmProjects\texts_attribution\venv\Lib\site-packages\corus\sources\wiki.py:7
#       5 from corus.record import Record
#       6 from corus.io import load_bz2_lines
# ----> 7 from corus.third.WikiExtractor import (
#       8     options,
#       9     pages_from,
#      10     Extractor
#      11 )
#      14 options.write_json = True
#      17 class WikiRecord(Record):
#
# File ~\PycharmProjects\texts_attribution\venv\Lib\site-packages\corus\third\WikiExtractor.py:2447
#    2445 EXT_LINK_URL_CLASS = r'[^][<>"\x00-\x20\x7F\s]'
#    2446 ANCHOR_CLASS = r'[^][\x00-\x08\x0a-\x1F]'
# -> 2447 ExtLinkBracketedRegex = re.compile(
#    2448     '\[(((?i)' + '|'.join(wgUrlProtocols) + ')' + EXT_LINK_URL_CLASS + r'+)' +
#    2449     r'\s*((?:' + ANCHOR_CLASS + r'|\[\[' + ANCHOR_CLASS + r'+\]\])' + r'*?)\]',
#    2450     re.S | re.U)
#    2451 # A simpler alternative:
#    2452 # ExtLinkBracketedRegex = re.compile(r'\[(.*?)\](?!])')
#    2454 EXT_IMAGE_REGEX = re.compile(
#    2455     r"""^(http://|https://)([^][<>"\x00-\x20\x7F\s]+)
#    2456     /([A-Za-z0-9_.,~%\-+&;#*?!=()@\x80-\xFF]+)\.((?i)gif|png|jpg|jpeg)$""",
#    2457     re.X | re.S | re.U)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\__init__.py:227, in compile(pattern, flags)
#     225 def compile(pattern, flags=0):
#     226     "Compile a regular expression pattern, returning a Pattern object."
# --> 227     return _compile(pattern, flags)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\__init__.py:294, in _compile(pattern, flags)
#     288     import warnings
#     289     warnings.warn("The re.TEMPLATE/re.T flag is deprecated "
#     290               "as it is an undocumented flag "
#     291               "without an obvious purpose. "
#     292               "Don't use it.",
#     293               DeprecationWarning)
# --> 294 p = _compiler.compile(pattern, flags)
#     295 if not (flags & DEBUG):
#     296     if len(_cache) >= _MAXCACHE:
#     297         # Drop the oldest item
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_compiler.py:743, in compile(p, flags)
#     741 if isstring(p):
#     742     pattern = p
# --> 743     p = _parser.parse(p, flags)
#     744 else:
#     745     pattern = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_parser.py:980, in parse(str, flags, state)
#     977 state.flags = flags
#     978 state.str = str
# --> 980 p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     981 p.state.flags = fix_flags(str, p.state.flags)
#     983 if source.next is not None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_parser.py:455, in _parse_sub(source, state, verbose, nested)
#     453 start = source.tell()
#     454 while True:
# --> 455     itemsappend(_parse(source, state, verbose, nested + 1,
#     456                        not nested and not items))
#     457     if not sourcematch("|"):
#     458         break
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_parser.py:863, in _parse(source, state, verbose, nested, first)
#     860     group = None
#     861 sub_verbose = ((verbose or (add_flags & SRE_FLAG_VERBOSE)) and
#     862                not (del_flags & SRE_FLAG_VERBOSE))
# --> 863 p = _parse_sub(source, state, sub_verbose, nested + 1)
#     864 if not source.match(")"):
#     865     raise source.error("missing ), unterminated subpattern",
#     866                        source.tell() - start)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_parser.py:455, in _parse_sub(source, state, verbose, nested)
#     453 start = source.tell()
#     454 while True:
# --> 455     itemsappend(_parse(source, state, verbose, nested + 1,
#     456                        not nested and not items))
#     457     if not sourcematch("|"):
#     458         break
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_parser.py:863, in _parse(source, state, verbose, nested, first)
#     860     group = None
#     861 sub_verbose = ((verbose or (add_flags & SRE_FLAG_VERBOSE)) and
#     862                not (del_flags & SRE_FLAG_VERBOSE))
# --> 863 p = _parse_sub(source, state, sub_verbose, nested + 1)
#     864 if not source.match(")"):
#     865     raise source.error("missing ), unterminated subpattern",
#     866                        source.tell() - start)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_parser.py:455, in _parse_sub(source, state, verbose, nested)
#     453 start = source.tell()
#     454 while True:
# --> 455     itemsappend(_parse(source, state, verbose, nested + 1,
#     456                        not nested and not items))
#     457     if not sourcematch("|"):
#     458         break
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\_parser.py:841, in _parse(source, state, verbose, nested, first)
#     839 if flags is None:  # global flags
#     840     if not first or subpattern:
# --> 841         raise source.error('global flags not at the start '
#     842                            'of the expression',
#     843                            source.tell() - start)
#     844     verbose = state.flags & SRE_FLAG_VERBOSE
#     845     continue
#
# error: global flags not at the start of the expression at position 4

# %%
load_ods_meduza()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 load_ods_meduza()
#
# NameError: name 'load_ods_meduza' is not defined
